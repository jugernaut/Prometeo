# %% [markdown]
# <a href="https://colab.research.google.com/github/jugernaut/Prometeo/blob/desarrollo/02_AlgebraLineal/01_Vectores/01_Vectores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Vectores
#
# ### Trabajo realizado con el apoyo del Programa UNAM-DGAPA-PAPIME PE101019
#
# *   Autor:
#   - Jaime Jesús Ortega Ibarra
# *   Rev: jueves dic 03 14:17:58 CDT 2020
#
# Este sitio puede ser usado libremente, tanto por profesores como por estudiantes, que deseen complementar sus cursos y conocimientos en los temas antes mencionados. Los materiales están bajo una Licencia Creative Commons Atribución-NoComercial-CompartirIgual 4.0 Internacional
#
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Licencia Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a><br />Esta obra está bajo una <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Licencia Creative Commons Atribución-NoComercial-CompartirIgual 4.0 Internacional</a>.
#
# Trabajo realizado con el apoyo del Programa UNAM-DGAPA-PAPIME PE101019

# %%
# COLAB
# !git clone https://github.com/jugernaut/Prometeo.git #rama  principal
#!git clone --branch desarrollo https://github.com/jugernaut/Prometeo.git #rama desarrollo 
# A continuación se importarán las librerías necesarias para la explicaión.
import Prometeo.Utils.gutils as vis

# Linux, MacOS y windows
# import os, sys
# sys.path.insert(0, os.path.abspath('../../'))
# import Utils.gutils as vis

import numpy as np
import math
# Out:
# Cloning into 'Prometeo'...
# remote: Enumerating objects: 220, done.
# remote: Counting objects: 100% (220/220), done.
# remote: Compressing objects: 100% (209/209), done.
# remote: Total 1915 (delta 131), reused 13 (delta 8), pack-reused 1695
# Receiving objects: 100% (1915/1915), 13.69 MiB | 25.45 MiB/s, done.
# Resolving deltas: 100% (1203/1203), done.

# %% [markdown]
# ## Introducción
#
# **¿Sabías que los juegos para niños, pueden verse como vectores?**\
# Cuando se tienen 2 o más columpios, estos pueden verse como vectores paralelos, ya que estos se mueven en una misma dirección, más no con la misma magitud, ya que el movimiento de ellos depende de la fuerza que se les aplique y el tiempo en el que se aplica dicha fuerza. Dentro de este notebook, aprenderemos qué es un vector, así algunas operaciones con estos.
#
# El término vector proviene del latín vector, vectoris, cuyo significado es 'el que conduce', o 'el que transporta'.
# Se le denomina vector de dimensión $n$ a una tupla de números reales (componentes del vector). El conjunto de todos los vectores de dimensión $n$, se representa como $\mathbb{R}^n$. Es decir, un vector $\vec{v}$ perteneciente a un espacio vectorial $\mathbb{R}^n$ se representa de la siguiente manera:\
# $\vec{v}=(a_{1},a_{2},a_{3},...,a_{n})$, donde $\vec{v} \in \mathbb{R}^n$
#
#    + **¿Qué es un vector?**\
# Dentro del área de la física, se le conoce como vector a un segmento de recta en el espacio que parte de un punto hacia otro, es decir, que tiene dirección y sentido. Los vectores en física tienen por función expresar las llamadas magnitudes vectoriales. En computación, un vector representa una lista de números que pueden tomar muchos valores.
# En matemáticas se define vector como un elemento de un espacio vectorial. Esta noción es más abstracta y para muchos espacios vectoriales no es posible representar sus vectores mediante el módulo y la dirección, en particular los espacios de dimensión infinita sin producto escalar no son representables de ese modo. Los vectores en un espacio euclídeo se pueden representar geométricamente como segmentos de recta $\mathbb{R}$, en el plano $\mathbb{R}^{2}$ (bidimensional), o en el espacio $\mathbb{R}^{3}$ (tridimensional).
#
# Mientras en el área de la computación, los vectores son una forma de almacenar datos que permiten contener una serie de valores del mismo tipo, cada uno de los valores contenidos tiene una posición asociada que se usará para accederlos. Está posición o índice será siempre un número entero positivo.

# %% [markdown]
# Dentro del lenguaje de programación $Python$ con ayuda de la biblioteca $Numpy$, podemos generar arreglos, los cuales vistos de otro modo pueden ser vectores.

# %%
# Declaramos a nuestra variable X, la cual mediante un arreglo de Numpy, representará a nuestro vector [1,2]
x = np.array([1, 2])
# desplazamiento en 1 sobre el eje de las x's y 2 en el eje y
print(f'Nuestro vector x es el siguiente: {x}')
# Out:
# Nuestro vector x es el siguiente: [1 2]

# %% [markdown]
# Podemos visualizar nuestro vector de la siguiente manera:

# %%
# Procedemos a realizar la gráfica de nuestro vector para una mejor visualización
par = [{'ylim':(0,3), 'xlim':(0,2)}]

graf = vis.planoCartesiano(par=par)
graf.plot(x=np.array([0, 1]), y=[0,2], par={'label':'Vector x', 'ls':'dashdot','lw':1, 'color':'blue'})
graf.scatter(x=np.array([0, 1]), y=[0,2], par={'ls':'dashdot','lw':4, 'color':'blue', 'marker':'v'})
graf.legend()
graf.show()

# %% [markdown]
# # Suma y resta de vectores
#
# Para sumar dos vectores $\vec{a}$  y $\vec{b}$ se suma $\vec{a}$ con el vector $\vec{b}$, es decir, se suman los componentes de cada vector:
#
# \begin{equation}
# \vec{a}+\vec{b} = (a_{1}+b_{1},a_{2}+b_{2},a_{3}+b_{3})
# \end{equation}

# %% [markdown]
# ### Ejemplo
#
# Sean $\vec{a}=(3,2,-4)$ y $\vec{b}=(-3,2,7)$, calcula el vector $\vec{a}+\vec{b}$
# \begin{equation}
# \vec{a}+\vec{b} = (3+(-3),2+2,-4+7)=(0,4,3)
# \end{equation}
#
# Para restar dos vectores $\vec a$ y $\vec b$ se suma $\vec a$ con el opuesto del vector $\vec b$, es decir:}
# \begin{equation}
# \vec a- \vec b = (\vec a_{1}- \vec b_{1}, \vec a_{2}- \vec b_{2},\vec a_{3}- \vec b_{3})
# \end{equation}
# Por ejemplo:\
# Sea $\vec a=(5,2,4)$ y $\vec b=(-3,5,9)$, calcular el vector $\vec a- \vec b$
# \begin{equation}
# \vec a- \vec b=(5-(-3),2-5,4-9)=(8,-3,-5)
# \end{equation}

# %% [markdown]
# Sumando y Restando Vectores, al vector $\vec x$ se le desea sumar otro vector $\vec y$

# %%
#Declaramos nuestro vector y
y = np.array([2, -1,])
print('Nuestro vector x es:\n', x)
print('Nuestro vector y es:\n', y, '\n')
#Utilizando los operadores aritmeticos + y -, realizamos las operaciones necesarias
print(f'La suma de nuestros vectores X y Y es: {x+y}')
print(f'La resta de nuestros vectores X y Y es: {x-y}')
# Out:
# Nuestro vector x es:
#  [1 2]
# Nuestro vector y es:
#  [ 2 -1]
#
# La suma de nuestros vectores X y Y es: [3 1]
# La resta de nuestros vectores X y Y es: [-1  3]

# %% [markdown]
# Visualizando el vector $\vec x$ y el vector $\vec y$

# %%
par = [{'title':'Grafica de Ambos Vectores','ylim':(-2,3), 'xlim':(0,3)}]
graf = vis.planoCartesiano(par=par)
graf.plot(x=np.array([0, 1]), y=[0,2], par={'label':'Vector x', 'ls':'dashdot','lw':1, 'color':'blue'})
graf.plot(x=np.array([0, 2]), y= [0,-1], par={'label':'Vector y', 'ls':':','lw':2, 'color':'red'})
graf.scatter(x=np.array([0, 1]), y= [0,2], par={ 'ls':'dashdot','lw':4, 'color':'blue','marker':'v'})
graf.scatter(x=np.array([0, 2]), y= [0,-1], par={ 'ls':':','lw':6, 'color':'red', 'marker':'v'})
graf.legend()
graf.show()

# %% [markdown]
# Visualizando el nuevo vector $\vec x - \vec y$ que nos dió un resultado de $(-1, 3)$ y $ \vec x + \vec y$ que nos dió $(3, 1)$

# %%
par = [{'title':'Suma y Resta de vectores','ylim':(-1,4), 'xlim':(-2,4)}]
graf = vis.planoCartesiano(par=par)
graf.plot(x=np.array([0, -1]), y=[0,3], par={'label':'Vector x+y', 'ls':'dashdot','lw':1, 'color':'blue'})
graf.plot(x=np.array([0, 3]), y=[0,1], par={'label':'Vector x-y', 'ls':':','lw':2, 'color':'red'})
graf.scatter(x=np.array([0, -1]), y=[0,3], par={ 'ls':'dashdot','lw':4, 'color':'blue','marker':'v'})
graf.scatter(x=np.array([0, 3]), y=[0,1], par={ 'ls':':','lw':5, 'color':'red','marker':'v'})
graf.legend()
graf.show()

# %% [markdown]
# # Multiplicación de un Vector por un escalar
#
# La multiplicación por un escalar proviene de la definición ya que este valor por el cuál vamos a multiplicar un vector en realidad solo va a agrandar ó a dismininuir la magnitud del vector (lo va a escalar).

# %% [markdown]
# ## Ejemplo
#
# Al multiplicar un vector $\vec{x}$ por un escalar $\lambda$, obtenemos como resultado un nuevo vector $\vec{y}=(\lambda)(\vec{x})$ que cumple con las siguientes características:\
# Si $\lambda$ es:\
# \
# ~ Positivo entonces $\vec{x}$ y $\vec{y}$ tendrán el mismo sentido.\
# ~ Negativo entonces $\vec{x}$ y $\vec{y}$ tendrán sentido opuesto.\
# \
# Por ejemplo:\
# Sea $\vec{x} =(2,4,1,2)$ y $\lambda=2$\
# \begin{equation}
# (\vec{x})(\lambda) = 2(2,4,1,2) = (4,8,2,4)
# \end{equation}
#
# No importa cuantas componentes tenga nuestro vector, el escalar $\lambda$ multiplica cada una de las componentes del vector. Un ejemplo en 2 dimensiones es el siguiente.

# %% [markdown]
# Para multiplicar un vector $\vec{x}$ por un escalar $\lambda$, únicamente definimos dicho escalar y realizamos el producto con nuestro arreglo.

# %%
#Asignamos una variable k representando nuestro escalar
k = 2
#Declaramos nuestro vector
vector = np.array([1, 3])
#Realizamos la multiplicación
producto = vector*k
print('Vector: ', vector, '\n')
print('Escalar: ', k, '\n')
print(f'El producto es: {producto}')
# Out:
# Vector:  [1 3]
#
# Escalar:  2
#
# El producto es: [2 6]

# %% [markdown]
# Cuando el escalar es positivo

# %%
par = [{'title':'Producto (+Escalar)(Vector)','ylim':(-3,9), 'xlim':(-0.5,3.5)}]
graf = vis.planoCartesiano(par=par)
graf.plot(x=np.array([0, 1]), y=[0,3], par={'label':'Vector', 'ls':'dashdot','lw':1, 'color':'blue'})
graf.plot(x=np.array([0, 2]), y= [0,6], par={'label':'Producto', 'ls':':','lw':2, 'color':'red'})
graf.scatter(x=np.array([0,1]), y=[0,3], par={ 'ls':'dashdot','lw':4, 'color':'blue','marker':'v'})
graf.scatter(x=np.array([0, 2]), y=[0,6], par={ 'ls':':','lw':6, 'color':'red','marker':'v'})
graf.legend()
graf.show()

# %% [markdown]
# Cuando el escalar es negativo, se tienen direcciones distintas

# %%
#Asignamos un valor para nuestro escalar
k = -2

#Realizamos la operación indicada
producto = vector*k
print('Escalar: ',k)
print(f'El producto es: {producto}')

par = [{'title':'Producto (-Escalar)(Vector)','ylim':(-7,4), 'xlim':(-3,2)}]
graf = vis.planoCartesiano(par=par)
graf.plot(x=np.array([0, 1]), y=[0,3], par={'label':'Vector', 'ls':'dashdot','lw':1, 'color':'blue'})
graf.plot(x=np.array([0, -2]), y= [0,-6], par={'label':'Producto', 'ls':':','lw':2, 'color':'red'})
graf.scatter(x=np.array([0,1]), y=[0,3], par={ 'ls':'dashdot','lw':4, 'color':'blue','marker':'v'})
graf.scatter(x=np.array([0, -2]), y=[0,-6], par={ 'ls':':','lw':6, 'color':'red','marker':'^'})
graf.legend()
graf.show()
# Out:
# Escalar:  -2
# El producto es: [-2 -6]

# %% [markdown]
# # Vector Unitario
# Un vector unitario hace referencia al vector cuyo módulo (distancia con respecto al origen) es igual a 1. Cabe recordar que el módulo es la cifra coincidente con la longitud cuando el vector se representa en un gráfico. El módulo, de este modo, es una <a href="../06_Normas/06_Normas.ipynb">norma</a> de la matemática que se aplica al vector que aparece en un espacio euclídeo.
# Para hallar un vector unitario a partir de cualquier vector, hay que dividir este último por su módulo.

# %% [markdown]
# ## Ejercicio
# Si $\vec{v}$ es un vector de componentes (3,4), encontrar un vector unitario de su misma dirección y sentido, dada la fórmula:
# \begin{equation}
# \vec{u} = \frac{1}{|\vec{v}|} \vec{v}
# \end{equation}
# - Calcular magnitud (norma) de $\vec{v}$
# \begin{equation}
# |\vec{u}| = \sqrt{(3)^2 + (4)^2} = \sqrt{25} = 5
# \end{equation}
# Sustituyendo:
# \begin{equation}
# \vec{u} = \frac{1}{5}(3,4) = (\frac{3}{5},\frac{4}{5})
# \end{equation}
# Visto desde código:

# %%
# Creamos una lista vacía para nuestro vector unitario y otra con valores para nuestro vector

vector_unitario = []
vector = [3,4]
#Calculando magnitud
magnitud = math.sqrt(vector[0]**2 + vector[1]**2)
#En el siguiente ciclo, almacenamos los valores de nuestro vector
for i in range(len(vector)):
  vector_unitario.append(vector[i]*(1/magnitud))
print('Vector original', vector)
print('Nuestro vector unitario es: ',vector_unitario)
# Out:
# Vector original [3, 4]
# Nuestro vector unitario es:  [0.6000000000000001, 0.8]

# %%
par = [{'title':'Vector Unitario','ylim':(0,4.5), 'xlim':(0,3.5)}]
graf = vis.planoCartesiano(par=par)
graf.plot(x=np.array([0, 3]), y=[0,4], par={'label':'Vector', 'ls':'dashdot','lw':1, 'color':'blue'})
graf.plot(x=np.array([0, 0.6]), y= [0,0.8], par={'label':'Vector Unitario', 'ls':':','lw':2, 'color':'red'})
graf.scatter(x=np.array([0, 3]), y=[0,4], par={ 'ls':'dashdot','lw':4, 'color':'blue','marker':'v'})
graf.scatter(x=np.array([0, 0.6]), y=[0,0.8], par={ 'ls':':','lw':6, 'color':'red','marker':'v'})
graf.legend()
graf.show()

# %% [markdown]
# # Producto Punto
#
# El producto punto o producto escalar de dos vectores es una operación que da como resultado un número real. Hay distintas formas de definir esta operación, una de ellas es por medio de multiplicar el producto de los módulos de los vectores por el coseno del ángulo que forman, esto es:
#
# \begin{equation}
# \vec{u} \cdot \vec{v} = |\vec{u}||\vec{v}| \cos{\alpha}
# \end{equation}
#
# Sin embargo, la forma más común de definir el producto punto no es esa, sino por medio de la suma de los productos de sus respecticas coordenadas, es decir, si $$\vec{u} = (u_1, u_2, \dots, u_n)$$ y $$\vec{v} = (v_1, v_2, \dots, v_n)$$, entonces podemos definir el producto punto como:
#
#  $$\vec{u} \cdot \vec{v} = u_1v_1 + u_2v_2 + \cdots + u_nv_n = \sum_{i=1}^{n}{u_iv_i}$$

# %% [markdown]
# ## Ejemplo
# Hallar el producto punto de dos vectores cuyas coordenadas son las siguientes:
#
# $$\vec{v} = \left( 1, \frac{1}{2}, 3\right), \qquad \vec{u} = \left(4, -4, 1\right).$$
#
# Aplicando la definición, tenemos que
#
#
#
# \begin{align*}
# \vec{v} \cdot \vec{u} &= \left( 1, \frac{1}{2}, 3\right) \cdot \left(4, -4, 1\right)\\&= (1)(4) + \left( \frac{1}{2}\right) (-4) + (3)(1)\\&= 4 - 2 + 3\\&= 5
# \end{align*}
#
#
#
# Esto visto desde $Python$ podemos utilizar la librería de $Numpy$ con su función $dot()$
#
# Por ejemplo:

# %%
#Tomando los vectores anteriores
v = [1, 1/2, 3]
u = [4, -4, 1]


#Mediante dot obtenemos el producto punto de ambos vectores

print("El producto punto es: ", np.dot(v,u))
# Out:
# El producto punto es:  5.0

# %% [markdown]
# # Ortogonalidad
# Dos vectores son ortogonales o perpendiculares si su producto escalar es cero, es decir:
# $$\vec{u} \cdot \vec{v} = 0$$
#
#
#
# $$v_1 \cdot u_1, v_2 \cdot u_2,...,v_n \cdot u_n = 0$$
#
# ## Ejercicio
# Determinar si los vectores $\vec{a}$ = (1, 2)  y  $\vec{b}$ = (-2, 1) son ortogonales.
#
# Como $$\vec{a} = (1, 2) y \vec{b} = (-2, 1),$$  entonces:
#
# $$\vec{a} \cdot \vec{b} = (1)(-2) + (2)(1) = 0 $$
#
# $\therefore$ Son Ortogonales

# %%
# Comprobando mediante Python
a = [1,2]
b = [-2,1]

# Realizando producto punto
producto = np.dot(a,b)

# Si el producto punto de ambos vectores da como resultado 0,
# estos son ortogonales
if producto == 0:
  print('Nuestros vectores son ortogonales, con un producto = ', producto)
else:
  print('Nuestros vectores no son ortogonales, con un producto = ', producto)
# Out:
# Nuestros vectores son ortogonales, con un producto =  0

# %% [markdown]
# # Ejercicio

# %% [markdown]
# ## Un partido de football
# En un juego de futbol americano, un mariscal de campo toma el balón desde la línea de golpeo, corre hacia atrás una distancia de $10$ yardas y luego corre de manera lateral, paralelo a la línea de golpeo $15$ yardas. En este punto lanza un pase recto hacia adelante $50$ yardas, perpendicular a la línea de golpeo, ¿Cuál es la magnitud de desplazamiento del balón?.

# %%
# A continuación realizaremos la gráfica del ejercicio anterior
par = [{'title':'Campo de Juego','ylim':(41,-11), 'xlim':(-0.25,16)}]
vectores = [[15, 40], [15, -10]]
graf = vis.planoCartesiano(par=par)
graf.plot(x=np.array([15, 15]), y=np.array([-10, 40]), par={'label':'','lw':2, 'ls':'--','color':'blue'})
graf.plot(x=np.array([0, 15]), y= np.array([0, -10]), par={'label':'','lw':2,'ls':'--', 'color':'red'})
graf.scatter(x=np.array([15, 15]), y=np.array([-10, 40]), par={ 'label':'Pase','lw':3, 'color':'blue','marker':'v'})
graf.scatter(x=np.array([0, 15]), y= np.array([0, -10]), par={'label':'Desplazamiento Qb.','lw':3, 'color':'red'})
graf.plot(x=[0,16],y=[0,0],par={'label':'Línea de golpeo','c':'green','ls':'--','lw':2})

graf.ticks()
graf.legend(par={'loc':'lower center'})
graf.show()

# %% [markdown]
# Comprobando
#
# \begin{equation}
# Desplazamiento\ en\ y \sum dy = -10+50 = 40
# \end{equation}
# \
# \begin{equation}
# Desplazamiento\ en\ x \sum dx = 15
# \end{equation}
# \
# \begin{equation}
# Desplazamiento\ total\ dt = 15\ yardas + 40\ yardas
# \end{equation}
# \
# $$|d| = \sqrt{(15)^2 + (40)^2 }$$
# \
# $$|d| = \sqrt{225 + 1600}$$
# \
# $$|d| = \sqrt{1825}$$
# \
# $$Desplazamiento\ totla\ del\ balón\ =\ |d| = 42.72\ yardas$$
# \
# $\therefore$ La magnitud del desplazamiento del balón es de $42.72$ yardas

# %%
dy = -10 + 50
dx = 15
dt = dy + dx

#Con ayuda de la biblioteca Math, podemos realizar raíz cuadrada mediante la función sqrt()
d = math.sqrt((15**2)+(40**2))
print('La magnitud del desplazamiento resultante del balón es: ', d, ' yardas')
# Out:
# La magnitud del desplazamiento resultante del balón es:  42.720018726587654  yardas

# %% [markdown]
# #Referencias
#
# Para mayor aprendizaje se recomienda al lector visitar las diversas fuentes de donde se obtuvo la información anterior:
# - https://www.fisicalab.com/apartado/producto-de-vector-y-escalar
# - https://www.educaplus.org/movi/1_4sumavector.html \
# - http://euclides.us.es/da/apuntes/alige/alige-I-4.pdf

# %% [markdown]
# #Evalúa tu conocimiento
#
# Si deseas contestar un breve cuestionario en el que podras evaluar un poco del conocimiento aquirido en este notebook da clic en el siguiente enlace:
#
# https://docs.google.com/forms/d/e/1FAIpQLSeXRmwMTfXp2FdNxIWluRi6dTnp1KtFeYGVcrgQXMta-rRWrw/viewform?usp=sf_link
